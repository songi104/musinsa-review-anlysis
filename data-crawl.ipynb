# %%
from google_play_scraper import reviews
from datetime import datetime
import pandas as pd

# %%
result, continuation_token = reviews("com.musinsa.store", lang="ko", country="kr")
cnt = 0

while True:
    cnt += 1
    print(f"{cnt}번째 크롤링 중...")
    tlst, continuation_token = reviews("com.musinsa.store", lang="ko", country="kr", continuation_token=continuation_token)
    result += tlst
    last = result[-1]["at"]
    
    if cnt == 19:
        break
# Out:
# 1번째 크롤링 중...
# 2번째 크롤링 중...
# 3번째 크롤링 중...
# 4번째 크롤링 중...
# 5번째 크롤링 중...
# 6번째 크롤링 중...
# 7번째 크롤링 중...
# 8번째 크롤링 중...
# 9번째 크롤링 중...
# 10번째 크롤링 중...
# 11번째 크롤링 중...
# 12번째 크롤링 중...
# 13번째 크롤링 중...
# 14번째 크롤링 중...
# 15번째 크롤링 중...
# 16번째 크롤링 중...
# 17번째 크롤링 중...
# 18번째 크롤링 중...
# 19번째 크롤링 중...

# %%
print(f"{len(result)}개가 크롤링됐어요")
print(result[-1]["at"])
print(type(result[-1]["at"]))
# Out:
# 2000개가 크롤링됐어요
# 2024-03-27 22:00:08
# <class 'datetime.datetime'>

# %%
test = result[4]
for k, v in test.items():
    print(f"{k}: {v}")
# Out:
# reviewId: 072e2e47-f934-46d5-a4fd-dc916f6c5bcb
# userName: 원이솔
# userImage: https://play-lh.googleusercontent.com/a-/ALV-UjUOWAgWxziHmHQx1wQy7Te_URJYybXzZc3vx5r8bwoaICfj0OM
# content: 사용하기좋아요
# score: 5
# thumbsUpCount: 0
# reviewCreatedVersion: None
# at: 2025-02-06 20:14:12
# replyContent: None
# repliedAt: None
# appVersion: None

# %%
df = pd.DataFrame(result)
df
# Out:
#                                   reviewId      userName  \
# 0     9d1fa130-7d14-4c4b-8c33-477fd9d135ee  Yong-whe Koo
# 1     f6b7583a-7194-4bc2-b723-91f70ccf0aee           이건우
# 2     e3c01ba4-25cc-4660-9e04-9384fdd940c0           백현주
# 3     90a054b5-bbfa-4558-b39f-d93d47a039b7           박승찬
# 4     072e2e47-f934-46d5-a4fd-dc916f6c5bcb           원이솔
# ...                                    ...           ...
# 1995  ed897673-5623-4c23-ab70-26cd0eabf8d1           O Y
# 1996  7f29ff76-7b76-4fe6-822b-e70bfad0271e            앙마
# 1997  db1b0484-0167-444c-a520-ee43ab85abca            베이
# 1998  8f6f0b20-fcf5-4bab-9d26-3e3de1ef06ab     Juhee Yoo
# 1999  b572d901-313b-4874-be57-3c5fb0a18e61           김문심
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# 2     https://play-lh.googleusercontent.com/a/ACg8oc...
# 3     https://play-lh.googleusercontent.com/a/ACg8oc...
# 4     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                 ...
# 1995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 0                                      혜택도 다양하고 물건고 다양함      5              0
# 1     제품마다 적립금 사용제한이 있는 건 무슨 경우인가요? 적립금을 많이 쓰려면 그만큼 ...      1              4
# 2               첫 회원가입 후 쿠폰과 적립금등 큰혜택으로 주문시 기분이가 좋았습니다.      5              0
# 3                       좋은데 로켓배송에 익숙해져 있어 매우매우 참기가 힘듬..      5              0
# 4                                               사용하기좋아요      5              0
# ...                                                 ...    ...            ...
# 1995                                      무신사 넘흐나 사랑합니다      5              0
# 1996                          업데이트되더니 출석체크 오류났어요... 해결점      3              0
# 1997                        최신 버전을 설치했는데 왜 출석이 안됨? 장난하나      1              0
# 1998                                       업데이트 오류 있는 듯      1              0
# 1999  업데이트 후 출석체크 안되고 계속 업데이트하라고하네요. 5번이나 제거하고 다시 깔았...      3              1
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                    None 2025-02-07 09:04:38         None       NaT
# 1                    None 2025-02-07 03:16:21         None       NaT
# 2                  4.21.0 2025-02-07 00:27:38         None       NaT
# 3                  4.20.1 2025-02-07 00:22:08         None       NaT
# 4                    None 2025-02-06 20:14:12         None       NaT
# ...                   ...                 ...          ...       ...
# 1995               3.82.0 2024-03-28 04:28:46         None       NaT
# 1996               3.84.0 2024-03-28 00:52:08         None       NaT
# 1997               3.84.0 2024-03-27 23:50:17         None       NaT
# 1998               3.84.0 2024-03-27 23:05:34         None       NaT
# 1999               3.84.0 2024-03-27 22:00:08         None       NaT
#
#      appVersion
# 0          None
# 1          None
# 2        4.21.0
# 3        4.20.1
# 4          None
# ...         ...
# 1995     3.82.0
# 1996     3.84.0
# 1997     3.84.0
# 1998     3.84.0
# 1999     3.84.0
#
# [2000 rows x 11 columns]

# %%
# 데이터 전처리(버전확인)
#newest_df = df[df["reviewCreatedVersion"] == "1.2.324"]

# 필요한 열만
# newest_df = newest_df[["reviewId", "userName", "content", "score", "thumbsUpCount", "at"]]
df = df[["reviewId", "userName", "content", "score", "thumbsUpCount", "at"]]

# %%
import time
now = str(time.strftime("%y%m%d"))
now
# Out:
# '250208'

# %%
df.to_excel(now+"_review_data.xlsx")
